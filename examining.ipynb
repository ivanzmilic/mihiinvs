# %%
import numpy as np 
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
test = fits.open('/dat/milic/Na_MiHi/plage/obs01/mihi_sp/lr0500/cubeseries_Na.fits')[0].data

# %%
test.shape
# Out:
# (481, 128, 140, 4, 160)

# %%
# plot example Stokes
plt.figure(figsize=(10,8))
plt.plot(test[220,15,10,3,:], label='I')
