# %%
import numpy as np 
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
test = fits.open('/dat/milic/MiHI_Na_I_plage/plage/obs01/mihi_sp/lr0500/cubeseries_Na_cori.fits')[0].data

# %%
test.shape
# Out:
# (5, 124, 136, 2, 440)

# %%
# plot example Stokes
plt.figure(figsize=(10,8))
plt.plot(test[0,15,10,0,:], label='I')

# %%
plt.imshow(np.mean(test[0,:,:,0,:],axis=2).T, origin='lower',cmap='gray')
